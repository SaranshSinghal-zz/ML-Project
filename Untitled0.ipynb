# %% [markdown]
# <a href="https://colab.research.google.com/github/SaranshSinghal/Project/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Exploratory Data Analysis of Car Features**

# %% [markdown]
# ![1 T3FY-QKyhn2LHb9ZdlJ7yQ.png](data:image/png;base64,...)

# %% [markdown]
# ## Introduction

# %% [markdown]
# ### **What is Exploratory Data Analysis?**

# %% [markdown]
# Exploratory Data Analysis or (EDA) is understanding the data sets by summarizing their main characteristics often plotting them visually. This step is very important especially when we arrive at modeling the data in order to apply Machine learning. Plotting in EDA consists of Histograms, Box plot, Scatter plot and many more. It often takes much time to explore the data. Through the process of EDA, we can ask to define the problem statement or definition on our data set which is very important.

# %% [markdown]
# ### **How to perform Exploratory Data Analysis?**

# %% [markdown]
# This is one such question that everyone is keen on knowing the answer. Well, the answer is it depends on the data set that you are working. There is no one method or common methods in order to perform EDA, whereas in this tutorial you can understand some common methods and plots that would be used in the EDA process.

# %% [markdown]
# ### **What data are we exploring today?**

# %% [markdown]
# Since I am a huge fan of cars, I got a very beautiful data-set of cars from Kaggle. The data-set can be downloaded from here. To give a piece of brief information about the data set this data contains more of 10, 000 rows and more than 10 columns which contains features of the car such as Engine Fuel Type, Engine Size, HP, Transmission Type, highway MPG, city MPG and many more. So in this tutorial, we will explore the data and make it ready for modeling.

# %% [markdown]
# ## 1. Loading the Data, Scrubbing and Formatting

# %% [markdown]
# ### 1.1 Importing Dataset and Libraries

# %% [markdown]
# Below we are importing the python libraries in order to perform EDA on our dataset.

# %%
import pandas as pd                 #for prepocessing
import numpy as np                  #for prepocessing
import seaborn as sns               #for visualization
import matplotlib.pyplot as plt     #for visualization
# %matplotlib inline
sns.set(color_codes = True)
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# ### 1.1 Loading data into the dataframe

# %% [markdown]
# Loading the data into the pandas data frame is certainly one of the most important steps in EDA, as we can see that the value from the data set is comma-separated. So all we have to do is to just read the CSV into a data frame and pandas data frame does the job for us.

# %%
df = pd.read_csv('data.csv')

# Reading the data-set, loading the csv file information into df.

# %%
# Displaying the top 5 rows of the dataset.
df.head(5)
# Out:
#   Make       Model  Year  ... city mpg  Popularity   MSRP
# 0  BMW  1 Series M  2011  ...       19        3916  46135
# 1  BMW    1 Series  2011  ...       19        3916  40650
# 2  BMW    1 Series  2011  ...       20        3916  36350
# 3  BMW    1 Series  2011  ...       18        3916  29450
# 4  BMW    1 Series  2011  ...       18        3916  34500
#
# [5 rows x 16 columns]

# %%
# Displaying the last 5 rows of the dataset.
df.tail(5)
# Out:
#           Make   Model  Year  ... city mpg  Popularity   MSRP
# 11909    Acura     ZDX  2012  ...       16         204  46120
# 11910    Acura     ZDX  2012  ...       16         204  56670
# 11911    Acura     ZDX  2012  ...       16         204  50620
# 11912    Acura     ZDX  2013  ...       16         204  50920
# 11913  Lincoln  Zephyr  2006  ...       17          61  28995
#
# [5 rows x 16 columns]

# %%
# Checking the column names of the dataset.
df.columns

#displays the columns in the dataframe
# Out:
# Index(['Make', 'Model', 'Year', 'Engine Fuel Type', 'Engine HP',
#        'Engine Cylinders', 'Transmission Type', 'Driven_Wheels',
#        'Number of Doors', 'Market Category', 'Vehicle Size', 'Vehicle Style',
#        'highway MPG', 'city mpg', 'Popularity', 'MSRP'],
#       dtype='object')

# %% [markdown]
# ### 1.2 Checking the type of data and getting the statistical summary

# %% [markdown]
# Here we check for the datatypes because sometimes the MSRP or the price of the car would be stored as a string or object, if in that case, we have to convert that string to the integer data only then we can plot the data via a graph. Here, in this case, the data is already in integer format so nothing to worry.

# %%
df.info()

#infoinformation about each of the column (null values and dtype)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11914 entries, 0 to 11913
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Make               11914 non-null  object
#  1   Model              11914 non-null  object
#  2   Year               11914 non-null  int64
#  3   Engine Fuel Type   11911 non-null  object
#  4   Engine HP          11845 non-null  float64
#  5   Engine Cylinders   11884 non-null  float64
#  6   Transmission Type  11914 non-null  object
#  7   Driven_Wheels      11914 non-null  object
#  8   Number of Doors    11908 non-null  float64
#  9   Market Category    8172 non-null   object
#  10  Vehicle Size       11914 non-null  object
#  11  Vehicle Style      11914 non-null  object
#  12  highway MPG        11914 non-null  int64
#  13  city mpg           11914 non-null  int64
#  14  Popularity         11914 non-null  int64
#  15  MSRP               11914 non-null  int64
# ...

# %%
# Providing additional data like count, mean, std, min, max for numerical values in the dataframe
df.describe()
# Out:
#                Year    Engine HP  ...    Popularity          MSRP
# count  11914.000000  11845.00000  ...  11914.000000  1.191400e+04
# mean    2010.384338    249.38607  ...   1554.911197  4.059474e+04
# std        7.579740    109.19187  ...   1441.855347  6.010910e+04
# min     1990.000000     55.00000  ...      2.000000  2.000000e+03
# 25%     2007.000000    170.00000  ...    549.000000  2.100000e+04
# 50%     2015.000000    227.00000  ...   1385.000000  2.999500e+04
# 75%     2016.000000    300.00000  ...   2009.000000  4.223125e+04
# max     2017.000000   1001.00000  ...   5657.000000  2.065902e+06
#
# [8 rows x 8 columns]

# %%
# Total no. of rows and columns of the dataframe.
df.shape
# Out:
# (11914, 16)

# %% [markdown]
# ## 2. Dropping irrelevent columns

# %% [markdown]
# This step is certainly needed in EDA because sometimes there would be columns that we never use and in such cases dropping is useful. In this case, the column such as Market Category may not be very relevant.

# %%
# Dropping the irrelevant columns.
df = df.drop(['Market Category'], axis = 1)

# %%
# Checking the dataframe, if the change is applied.
df.head()
# Out:
#   Make       Model  Year  ... city mpg  Popularity   MSRP
# 0  BMW  1 Series M  2011  ...       19        3916  46135
# 1  BMW    1 Series  2011  ...       19        3916  40650
# 2  BMW    1 Series  2011  ...       20        3916  36350
# 3  BMW    1 Series  2011  ...       18        3916  29450
# 4  BMW    1 Series  2011  ...       18        3916  34500
#
# [5 rows x 15 columns]

# %% [markdown]
# ## 3. Renaming the Columns

# %% [markdown]
# In this instance, most of the column names are very confusing to read, so just tweak their column names. This is a good approach it improves the readability of the data set.

# %%
# Renaming columns for better accessibility.
df = df.rename(columns = {'Engine HP' : 'HP', 'Engine Cylinders' : 'Cylinders', 'Transmission Type' : 'Transmission', 'Driven_Wheels' : 'Drive Mode', 'highway MPG' : 'MPG-H', 'city mpg' : 'MPG-C', 'MSRP' : 'Price'})
df.head()
# Out:
#   Make       Model  Year  ... MPG-C  Popularity  Price
# 0  BMW  1 Series M  2011  ...    19        3916  46135
# 1  BMW    1 Series  2011  ...    19        3916  40650
# 2  BMW    1 Series  2011  ...    20        3916  36350
# 3  BMW    1 Series  2011  ...    18        3916  29450
# 4  BMW    1 Series  2011  ...    18        3916  34500
#
# [5 rows x 15 columns]

# %% [markdown]
# ## 4. Checking Duplicate Rows, Null Values and Missing Data

# %% [markdown]
# ### 4.1 Dropping the Duplicate Rows

# %% [markdown]
# This is often a handy thing to do because a huge data set as this dataset contains more than 10, 000 rows. Such large dataset often have some duplicate data which might be disturbing, so here we remove all the duplicate value from the dataset.

# %% [markdown]
# So for this, let's determine how many rows we have and how many of them are duplicates.

# %%
# Checking the total no. of rows and columns remaining.
df.shape
# Out:
# (11914, 15)

# %%
# Rows containing duplicate data.
d_rows_df = df[df.duplicated()]
print("Duplicated data: -\n", d_rows_df)
# Out:
# Duplicated data: -
#           Make     Model  Year  ... MPG-C  Popularity  Price
# 14        BMW  1 Series  2013  ...    19        3916  31500
# 18       Audi       100  1992  ...    17        3105   2000
# 20       Audi       100  1992  ...    17        3105   2000
# 24       Audi       100  1993  ...    17        3105   2000
# 25       Audi       100  1993  ...    17        3105   2000
# ...       ...       ...   ...  ...   ...         ...    ...
# 11481  Suzuki      X-90  1998  ...    22         481   2000
# 11603   Volvo      XC60  2017  ...    20         870  46350
# 11604   Volvo      XC60  2017  ...    23         870  40950
# 11708  Suzuki       XL7  2008  ...    15         481  29149
# 11717  Suzuki       XL7  2008  ...    16         481  27499
#
# [720 rows x 15 columns]

# %% [markdown]
# Therefore, we have to remove these duplicate 720 rows. For this, we will count the no. of rows first.

# %%
# Counting the rows before removing.
df.count()
# Out:
# Make                11914
# Model               11914
# Year                11914
# Engine Fuel Type    11911
# HP                  11845
# Cylinders           11884
# Transmission        11914
# Drive Mode          11914
# Number of Doors     11908
# Vehicle Size        11914
# Vehicle Style       11914
# MPG-H               11914
# MPG-C               11914
# Popularity          11914
# Price               11914
# dtype: int64

# %% [markdown]
# Now, we go ahead and remove the duplicate rows for the dataframe.

# %%
# Removing the duplicate rows.
df = df.drop_duplicates()
df.count()
# Out:
# Make                11194
# Model               11194
# Year                11194
# Engine Fuel Type    11191
# HP                  11125
# Cylinders           11164
# Transmission        11194
# Drive Mode          11194
# Number of Doors     11188
# Vehicle Size        11194
# Vehicle Style       11194
# MPG-H               11194
# MPG-C               11194
# Popularity          11194
# Price               11194
# dtype: int64

# %% [markdown]
# ### 4.2 Finding Missing and Null Values

# %%
# Finding the total null values.
print(df.isnull().sum())
# Out:
# Make                 0
# Model                0
# Year                 0
# Engine Fuel Type     3
# HP                  69
# Cylinders           30
# Transmission         0
# Drive Mode           0
# Number of Doors      6
# Vehicle Size         0
# Vehicle Style        0
# MPG-H                0
# MPG-C                0
# Popularity           0
# Price                0
# dtype: int64

# %%
df = df.dropna()
df.count()
# Out:
# Make                11092
# Model               11092
# Year                11092
# Engine Fuel Type    11092
# HP                  11092
# Cylinders           11092
# Transmission        11092
# Drive Mode          11092
# Number of Doors     11092
# Vehicle Size        11092
# Vehicle Style       11092
# MPG-H               11092
# MPG-C               11092
# Popularity          11092
# Price               11092
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Make                0
# Model               0
# Year                0
# Engine Fuel Type    0
# HP                  0
# Cylinders           0
# Transmission        0
# Drive Mode          0
# Number of Doors     0
# Vehicle Size        0
# Vehicle Style       0
# MPG-H               0
# MPG-C               0
# Popularity          0
# Price               0
# dtype: int64

# %%
# Dropping the missing values.
df = df.dropna()
df.count()
# Out:
# Make                11092
# Model               11092
# Year                11092
# Engine Fuel Type    11092
# HP                  11092
# Cylinders           11092
# Transmission        11092
# Drive Mode          11092
# Number of Doors     11092
# Vehicle Size        11092
# Vehicle Style       11092
# MPG-H               11092
# MPG-C               11092
# Popularity          11092
# Price               11092
# dtype: int64

# %%
# Checking if any more null values are left.
print(df.isnull().sum())
# Out:
# Make                0
# Model               0
# Year                0
# Engine Fuel Type    0
# HP                  0
# Cylinders           0
# Transmission        0
# Drive Mode          0
# Number of Doors     0
# Vehicle Size        0
# Vehicle Style       0
# MPG-H               0
# MPG-C               0
# Popularity          0
# Price               0
# dtype: int64

# %% [markdown]
# ## 5. Plotting the Graphs, Finding and Removing Outliers

# %% [markdown]
# ### 5.1 Plotting the Graphs

# %% [markdown]
# ### 5.2 Removing Outliers

# %%
#remove outliers by dropping the rows with values that are:
#greater than 50 in 'highway MPG'
#greater than 50 in 'city mpg'
#less than 500 in 'Popularity'
df.drop(df[df['highway MPG'] >= 50].index, inplace = True)
df.drop(df[df['city mpg'] >= 50].index, inplace = True)
df.drop(df[df['Popularity'] <= 500].index, inplace = True)
